# %% [markdown]
# Importing the Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %% [markdown]
# Reading the first 5 rows of the dataset

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 227806  145230.0 -0.985462  0.729666  0.225657 -0.889584  1.141207  0.927282
# 227807  145230.0 -1.795616  2.484787 -1.417975  0.916069 -0.235949 -1.060277
# 227808  145230.0  1.983763 -0.025189 -1.722203  0.483455  0.262805 -0.940571
# 227809  145230.0 -0.322168  0.344462 -0.343955 -0.405397  1.432666  1.039168
# 227810  145231.0 -1.623383  2.247979 -0.607712  0.799563  1.140861 -0.306731
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 227806  0.446918  0.804112 -0.797042  ...  0.004696 -0.055031 -0.040922
# 227807  0.191705  1.110801 -0.373248  ...  0.127368  0.437322 -0.115028
# 227808  0.199774 -0.216415  0.583095  ... -0.339345 -1.003262  0.322468
# 227809  0.567775  0.190750  0.228109  ...  0.393199  1.525731  0.171788
# 227810  1.036287  0.390841 -0.991510  ... -0.036866  0.078742 -0.551000
#
# ...

# %% [markdown]
# Getting the Important Information from the Dataset

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227811 entries, 0 to 227810
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    227811 non-null  float64
#  1   V1      227811 non-null  float64
#  2   V2      227811 non-null  float64
#  3   V3      227811 non-null  float64
#  4   V4      227811 non-null  float64
#  5   V5      227811 non-null  float64
#  6   V6      227811 non-null  float64
#  7   V7      227811 non-null  float64
#  8   V8      227811 non-null  float64
#  9   V9      227811 non-null  float64
#  10  V10     227811 non-null  float64
#  11  V11     227811 non-null  float64
#  12  V12     227811 non-null  float64
#  13  V13     227811 non-null  float64
#  14  V14     227811 non-null  float64
#  15  V15     227811 non-null  float64
#  16  V16     227811 non-null  float64
#  17  V17     227811 non-null  float64
#  18  V18     227811 non-null  float64
#  19  V19     227811 non-null  float64
# ...

# %%
#checking the numberof missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
# checking the legit distrubtion and fraudleunt distrubtion
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    227393
# 1.0       417
# Name: count, dtype: int64

# %% [markdown]
# THIS DATASET IS HIGHLY UNBALANCED

# %% [markdown]
# 0 --> Normal Tractions
#
# 1--> Fraudlent Tranctions

# %%
#seperating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (227393, 31)
# (417, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    227393.000000
# mean         90.768591
# std         250.504241
# min           0.000000
# 25%           6.000000
# 50%          23.420000
# 75%          79.970000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     417.000000
# mean      125.656379
# std       256.880976
# min         0.000000
# 25%         1.000000
# 50%        12.310000
# 75%       106.900000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare all the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    79054.125738 -0.057500 -0.020889  0.196667  0.035338 -0.057043
# 1.0    67308.333333 -5.381276  3.958775 -7.454069  4.655050 -3.775485
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.033051 -0.015454  0.002819  0.007174  ...  0.009268 -0.008029
# 1.0   -1.357987 -6.264641  0.663762 -2.696376  ...  0.376889  0.765659
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.022989 -0.009829  0.001235  0.038078  0.002754 -0.000146  0.001861
# 1.0    0.013088 -0.060036 -0.083433  0.051373  0.037788  0.202087  0.057439
#
#            Amount
# Class
# 0.0     90.768591
# 1.0    125.656379
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling
#
# Build a simple dataset containing the distrubtion of normal transactions and the fraudlent transactions
#
# Number of Fraudlent transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatinating Two Dataframes

# %%
new_dataset = pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 133884   80561.0  0.894258 -0.327235 -0.166174  1.135400 -0.030057  0.119024
# 187135  127402.0  0.146197  1.396414 -1.089761 -0.399857  1.690136 -1.273954
# 219195  141635.0 -0.765233  0.113183  1.186339 -0.690574  0.021877  0.072292
# 225194  144144.0  1.835381  0.250446  0.093580  3.746584  0.057806  0.835907
# 3253      2806.0 -0.416942  0.523771  1.167115 -2.082776 -0.046584 -1.343905
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 133884  0.240464  0.094359  0.039812  ...  0.099504  0.059479 -0.289118
# 187135  1.413676 -0.588993 -0.063952  ...  0.106470  0.599157 -0.459590
# 219195 -0.058994  0.170533  0.624334  ...  0.195993  0.675914 -0.061403
# 225194 -0.508361  0.179405 -0.407090  ...  0.187830  0.626348  0.184929
# 3253    0.940924 -0.196589  0.859889  ...  0.102784  0.542524 -0.259463
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 223572  143434.0 -2.729482  3.312495 -4.242710  5.036985 -0.376561 -1.532462
# 223578  143438.0 -5.256434  0.364541 -5.412085  2.400031  0.697301 -1.998755
# 223618  143456.0 -2.006582  3.676577 -5.463811  7.232058 -1.627859 -0.996755
# 226814  144808.0 -2.405207  2.943823 -7.616654  3.533374 -5.417494 -0.112632
# 226877  144839.0 -6.423306  1.658515 -5.866440  2.052064 -0.615817 -3.372266
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 223572 -3.449159  1.856839 -3.623334  ...  0.727415 -0.301432 -0.502433
# 223578 -5.835532 -0.887739 -2.828287  ... -0.648259  0.511285 -1.110045
# 223618 -4.299833  2.268867 -3.651067  ...  0.713907 -0.063868  0.167947
# 226814 -1.329372  1.709417 -2.322716  ...  0.652683  0.414132  0.023869
# 226877 -5.036556  2.643106 -2.274630  ...  0.641211 -0.256678 -2.337233
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    417
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    77496.577236 -0.070181 -0.083036  0.262926  0.048433 -0.093484
# 1.0    67308.333333 -5.381276  3.958775 -7.454069  4.655050 -3.775485
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.076895 -0.071757  0.063473 -0.056673  ...  0.014588 -0.000052
# 1.0   -1.357987 -6.264641  0.663762 -2.696376  ...  0.376889  0.765659
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0    0.032469 -0.037594  0.019182  0.025996  0.004237  0.003603  0.007541
# 1.0    0.013088 -0.060036 -0.083433  0.051373  0.037788  0.202087  0.057439
#
#            Amount
# Class
# 0.0     88.442378
# 1.0    125.656379
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features and Targets

# %%
x=new_dataset.drop(columns='Class',axis=1)
y=new_dataset['Class']

# %%
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 133884   80561.0  0.894258 -0.327235 -0.166174  1.135400 -0.030057  0.119024
# 187135  127402.0  0.146197  1.396414 -1.089761 -0.399857  1.690136 -1.273954
# 219195  141635.0 -0.765233  0.113183  1.186339 -0.690574  0.021877  0.072292
# 225194  144144.0  1.835381  0.250446  0.093580  3.746584  0.057806  0.835907
# 3253      2806.0 -0.416942  0.523771  1.167115 -2.082776 -0.046584 -1.343905
# ...          ...       ...       ...       ...       ...       ...       ...
# 223572  143434.0 -2.729482  3.312495 -4.242710  5.036985 -0.376561 -1.532462
# 223578  143438.0 -5.256434  0.364541 -5.412085  2.400031  0.697301 -1.998755
# 223618  143456.0 -2.006582  3.676577 -5.463811  7.232058 -1.627859 -0.996755
# 226814  144808.0 -2.405207  2.943823 -7.616654  3.533374 -5.417494 -0.112632
# 226877  144839.0 -6.423306  1.658515 -5.866440  2.052064 -0.615817 -3.372266
#
# ...

# %%
print(y)
# Out:
# 133884    0.0
# 187135    0.0
# 219195    0.0
# 225194    0.0
# 3253      0.0
#          ...
# 223572    1.0
# 223578    1.0
# 223618    1.0
# 226814    1.0
# 226877    1.0
# Name: Class, Length: 909, dtype: float64

# %% [markdown]
# Split the data into Training data and Testing data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x.shape,X_train.shape,X_test.shape)
# Out:
# (909, 30) (727, 30) (182, 30)

# %% [markdown]
# Model Training
#
# Logistic Regression

# %%
model=LogisticRegression()

# %%
 #Training the Logistic Regression model with Traing Dataset
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evalutation
#
# Accuracy Score

# %%
# accuracy in the taring dataset
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on traing data :', training_data_accuracy)
# Out:
# Accuracy on traing data : 0.951856946354883

# %% [markdown]
# accuracy test on test data

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy score on Test Data :',test_data_accuracy)
# Out:
# Accuracy score on Test Data : 0.9395604395604396

# %%
datainput = pd.read_csv('/content/creditcard.csv')

# %%
false = datainput[datainput['Class'] == 1]
true = datainput[datainput['Class'] == 1]
n=len(false)/float(len(true))
print(n)
print('fraud detection cases : {}'.format(len(datainput[datainput['Class']==1])))
print('normal detection cases : {}'.format(len(datainput[datainput['Class']==0])))
# Out:
# 1.0
# fraud detection cases : 417
# normal detection cases : 227393
